# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjin-Yoganantham/DAA---LAB-EXPERIMENTS/blob/main/Exp1compare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt

# Generate sorted roll number array (1 to 10000)
roll_numbers = list(range(1, 10001))

# Run bulk comparison on 50 random roll numbers
targets = random.sample(roll_numbers, 50)
interp_probes = []
binary_probes = []

for t in targets:
    _, ip, _ = interpolation_search(roll_numbers, t)
    _, bp, _ = binary_search(roll_numbers, t)
    interp_probes.append(ip)
    binary_probes.append(bp)

# Summary statistics
print(f"Interpolation → avg: {sum(interp_probes)/len(interp_probes):.2f} probes")
print(f"Binary Search  → avg: {sum(binary_probes)/len(binary_probes):.2f} probes")

# Plot comparison
plt.figure(figsize=(14, 5))
x = range(1, 51)
plt.plot(x, binary_probes,  'o-', color='#ff6b35', label='Binary Search',        linewidth=2)
plt.plot(x, interp_probes, 's-', color='#00d4ff', label='Interpolation Search', linewidth=2)
plt.xlabel('Sample Index'); plt.ylabel('Probes')
plt.title('Probe Count: Interpolation vs Binary Search (50 random roll numbers)')
plt.legend(); plt.grid(True, alpha=0.3); plt.tight_layout()
plt.savefig('search_comparison.png', dpi=150); plt.show()
